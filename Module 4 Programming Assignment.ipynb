# %%
# %%writefile zoo.py
    def hours():
    print('Open 9-5 daily')
# Out:
# Overwriting zoo.py

# %%
# 11.1
import zoo
zoo.hours()
# Out:
# Open 9-5 daily

# %%
# 11.2
import zoo as menagerie
menagerie.hours()
# Out:
# Open 9-5 daily
